# %%
import os
import csv
import numpy as np
import openai
import pandas as pd
from datetime import datetime
from pathlib import Path
from io import StringIO
import re

openai.api_key = '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'

# %%
"""
    Process and load csv's
"""
def process_one_csv(path: Path, n_keep: int = 10) -> pd.DataFrame:
    # Load csv keep column ids as strings
    df = pd.read_csv(
        path,
        dtype={"Topic_Clusters": str, "Topic_Sub_Clusters": str},
    )

    # All columns to the right of the first two are probabilities
    value_cols = df.columns[3:]
    df[value_cols] = df[value_cols].apply(pd.to_numeric, errors="coerce")

    # Build new columns as lists
    topic_ids, sub_ids, cluster_ids, topics_ls = [], [], [], []

    for _, row in df.iterrows():
        topic_ids.append(_)
        numeric_row = row[value_cols].astype(float)

        top = numeric_row.nlargest(n_keep)
        topics_ls.append([[term, round(float(weight), 6)] for term, weight in top.items()])

        # Normalize Subcluster ids
        raw = str(row["Topic_Sub_Clusters"])
        try:
            sub_ids.append(int(raw.split("_")[1]))
        except (IndexError, ValueError):
            sub_ids.append(-1)
        cluster_ids.append(row["Topic_Clusters"])

    # Form final iter dataframe
    new_cols = pd.DataFrame(
        {
            "file_name": os.path.basename(path)
            , "topic_id": topic_ids
            , "subcluster_id": sub_ids
            , "cluster_id": cluster_ids
            , "topics": topics_ls
        },
        index=df.index,
    )

    result = pd.concat([new_cols, df[value_cols]], axis=1)
    return result

INPUT_DIR = Path("input")
OUTPUT_DIR = Path("output")
OUTPUT_DIR.mkdir(exist_ok=True)

# Mainloop for extracting datasets from the input folder
result_matrix = []

for csv_file in INPUT_DIR.glob("*.csv"):
    inner_df = process_one_csv(csv_file, n_keep=5)
    result_matrix.append([csv_file.name, inner_df])

# Create a dataframe of file names, nested with their content
results_df = pd.DataFrame(result_matrix, columns=["file_name", "inner_df"])

# Preview header daatframe
print("\n===================Summary===================")
display(results_df[["file_name"]]) # list filenames

# Access first iteration of dataframe
first_inner = results_df.loc[0, "inner_df"]
print("\nFirst inner frame:")
display(first_inner.head())
# Out:
# ===================Summary===================
#                                            file_name
# 0  LDA_100_topic_word_norm_with_4_with_subcluster...
# First inner frame:
#                                            file_name  topic_id  subcluster_id  \
# 0  LDA_100_topic_word_norm_with_4_with_subcluster...         0              2
# 1  LDA_100_topic_word_norm_with_4_with_subcluster...         1              0
# 2  LDA_100_topic_word_norm_with_4_with_subcluster...         2              0
# 3  LDA_100_topic_word_norm_with_4_with_subcluster...         3              1
# 4  LDA_100_topic_word_norm_with_4_with_subcluster...         4              0
#
#   cluster_id                                             topics  absolutely  \
# 0          0  [[organic, 0.230976], [organic growth, 0.09574...    0.001398
# 1          0  [[aircraft, 0.061866], [united, 0.021051], [fl...    0.002064
# 2          0  [[plant, 0.064305], [packaging, 0.036433], [to...    0.000478
# 3          0  [[gross margin, 0.114848], [shipment, 0.040261...    0.000829
# 4          0  [[gas, 0.120051], [energy, 0.070837], [natural...    0.000520
#
#    acceleration  accounting  accretive   acquire  ...  year continue  \
# 0      0.001732    0.001052   0.001950  0.007201  ...       0.000886
# 1      0.000154    0.000530   0.000455  0.000113  ...       0.000904
# 2      0.000040    0.000118   0.000190  0.000659  ...       0.000515
# 3      0.000617    0.000190   0.000135  0.000577  ...       0.000257
# 4      0.000024    0.000167   0.000595  0.001406  ...       0.000352
#
#    year expect   year go  year look  year quarter  year see  year would  \
# 0     0.000650  0.000600   0.000764      0.000271  0.001249    0.000830
# 1     0.001611  0.001260   0.000902      0.000038  0.000725    0.000806
# 2     0.001234  0.000827   0.000812      0.000190  0.001275    0.000445
# 3     0.001337  0.000435   0.000246      0.000380  0.000895    0.000483
# 4     0.000527  0.000313   0.000459      0.000327  0.001072    0.000574
#
#    year year     yield          york
# 0   0.000386  0.000007  2.185418e-07
# 1   0.001476  0.002910  2.362675e-04
# 2   0.000632  0.000452  5.571611e-08
# 3   0.001292  0.000017  6.201966e-08
# 4   0.000510  0.000819  3.363482e-05
#
# [5 rows x 1005 columns]

# %%
"""
    Stores ChatGPT relabeling function. Takes a prompt and returns the result
"""
def get_chatgpt_response(prompt, model="gpt-4.1"):
    try:
        completion = openai.chat.completions.create(model=model,messages=[{"role": "user", "content": prompt}])
        return completion.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
"""
    Send initial prompt call for taking [(topic, weights), ...] to derive base level meanings
"""
base_prompt = (
    "In the context of an earnings call, the list of topics are relevant, with their relevancy nested in their decimal number weight"
    "Provide me back a 1-3 word description that summarizes them and use financial, economic, accounting language"
    "DO NOT RETURN ANYTHING OTHER THAN THE 1-3 WORD RESPONSE, THE SAKE OF THE WORLD DEPENDS ON IT"
    "\n\n"
)

for file_rec in results_df.itertuples(index=False):
    file_name = file_rec.file_name
    inner_df = file_rec.inner_df

    print(f"\n===================Processing rows from {file_name}===================")

    # Iterate through each loop of the inner dataframe
    for idx, row in inner_df.iterrows():
        subcluster_id = row["subcluster_id"]
        cluster_id = row["cluster_id"]
        topics = row["topics"]

        # Preview results as they are built
        print(f"row {idx:>4}: sub={subcluster_id}, clust={cluster_id}, "f"top term={topics[0][0]} (wt={topics[0][1]})", topics)
        
        prompt = base_prompt + f"Chunk of words:\n{topics}\n"
        caller = get_chatgpt_response(prompt, model="gpt-4.1")
        inner_df.at[idx, "topic_name"] = caller.strip()

print("\n===================Summary===================")
display(results_df[["file_name"]])

first_inner = results_df.loc[0, "inner_df"]
print("\nPreview frame results:")
display(first_inner.head())
# Out:
# ===================Processing rows from LDA_100_topic_word_norm_with_4_with_subclusters.csv===================
# row    0: sub=2, clust=0, top term=organic (wt=0.230976) [['organic', 0.230976], ['organic growth', 0.095748], ['organic revenue', 0.038918], ['services', 0.012626], ['organically', 0.012216]]
# row    1: sub=0, clust=0, top term=aircraft (wt=0.061866) [['aircraft', 0.061866], ['united', 0.021051], ['fleet', 0.020797], ['delivery', 0.020031], ['international', 0.015799]]
# row    2: sub=0, clust=0, top term=plant (wt=0.064305) [['plant', 0.064305], ['packaging', 0.036433], ['ton', 0.03458], ['export', 0.027069], ['brazil', 0.023463]]
# row    3: sub=1, clust=0, top term=gross margin (wt=0.114848) [['gross margin', 0.114848], ['shipment', 0.040261], ['new product', 0.024856], ['ship', 0.023289], ['ramp', 0.022372]]
# row    4: sub=0, clust=0, top term=gas (wt=0.120051) [['gas', 0.120051], ['energy', 0.070837], ['natural', 0.067073], ['natural gas', 0.047968], ['plant', 0.019523]]
# row    5: sub=0, clust=0, top term=fuel (wt=0.273163) [['fuel', 0.273163], ['stuff', 0.018555], ['card', 0.013833], ['macro', 0.013434], ['payment', 0.011778]]
# row    6: sub=0, clust=0, top term=oil (wt=0.063544) [['oil', 0.063544], ['production', 0.058597], ['barrel', 0.036315], ['basin', 0.024815], ['per day', 0.024602]]
# row    7: sub=0, clust=0, top term=profit (wt=0.051878) [['profit', 0.051878], ['engine', 0.039483], ['energy', 0.032886], ['backlog', 0.027403], ['equipment', 0.024807]]
# row    8: sub=0, clust=0, top term=indiscernible (wt=0.034393) [['indiscernible', 0.034393], ['recovery', 0.027926], ['money', 0.014853], ['government', 0.01149], ['stuff', 0.011431]]
# row    9: sub=0, clust=0, top term=energy (wt=0.049223) [['energy', 0.049223], ['utility', 0.026854], ['electric', 0.023424], ['transmission', 0.018362], ['gas', 0.017932]]
# row   10: sub=0, clust=0, top term=site (wt=0.065069) [['site', 0.065069], ['carrier', 0.054919], ['cell', 0.046804], ['network', 0.025179], ['deployment', 0.021257]]
# row   11: sub=0, clust=0, top term=automotive (wt=0.109821) [['automotive', 0.109821], ['industrial', 0.065444], ['auto', 0.017051], ['mobile', 0.015587], ['application', 0.012082]]
# row   12: sub=0, clust=0, top term=backlog (wt=0.147586) [['backlog', 0.147586], ['award', 0.047019], ['budget', 0.018174], ['booking', 0.010774], ['operate margin', 0.01042]]
# row   13: sub=0, clust=0, top term=industrial (wt=0.105819) [['industrial', 0.105819], ['oil', 0.082805], ['oil gas', 0.052892], ['gas', 0.049311], ['end market', 0.019079]]
# row   14: sub=1, clust=0, top term=digit (wt=0.073529) [['digit', 0.073529], ['china', 0.042952], ['single digit', 0.033316], ['double digit', 0.019879], ['life', 0.016609]]
# row   15: sub=0, clust=0, top term=production (wt=0.112404) [['production', 0.112404], ['ramp', 0.02202], ['delivery', 0.019673], ['government', 0.017198], ['safety', 0.015889]]
# row   16: sub=1, clust=0, top term=residential (wt=0.047703) [['residential', 0.047703], ['water', 0.043981], ['inflation', 0.037421], ['productivity', 0.02427], ['americas', 0.016992]]
# row   17: sub=0, clust=0, top term=wireless (wt=0.053412) [['wireless', 0.053412], ['network', 0.03354], ['mobile', 0.027814], ['phone', 0.027336], ['ebitda', 0.019849]]
# row   18: sub=2, clust=0, top term=organic (wt=0.075945) [['organic', 0.075945], ['restructuring', 0.037659], ['organic growth', 0.034538], ['operate margin', 0.027446], ['adjust operate', 0.021547]]
# row   19: sub=1, clust=0, top term=emerge (wt=0.065773) [['emerge', 0.065773], ['emerge market', 0.047828], ['innovation', 0.037369], ['china', 0.031652], ['latin', 0.018798]]
# row   20: sub=0, clust=0, top term=maintenance (wt=0.035967) [['maintenance', 0.035967], ['special', 0.029148], ['south', 0.028821], ['share repurchase', 0.019998], ['export', 0.017209]]
# row   21: sub=0, clust=0, top term=network (wt=0.23434) [['network', 0.23434], ['video', 0.069963], ['mobile', 0.010737], ['marketplace', 0.009705], ['connect', 0.008669]]
# row   22: sub=0, clust=0, top term=international (wt=0.120739) [['international', 0.120739], ['domestic', 0.067099], ['network', 0.028875], ['peak', 0.023997], ['profit', 0.023862]]
# row   23: sub=1, clust=0, top term=inflation (wt=0.069514) [['inflation', 0.069514], ['productivity', 0.026372], ['saving', 0.023169], ['gross margin', 0.022971], ['innovation', 0.021038]]
# row   24: sub=0, clust=0, top term=rig (wt=0.107211) [['rig', 0.107211], ['international', 0.04014], ['land', 0.018587], ['fleet', 0.018156], ['equipment', 0.015718]]
# row   25: sub=1, clust=0, top term=gross margin (wt=0.025491) [['gross margin', 0.025491], ['sequentially', 0.022875], ['china', 0.018018], ['ramp', 0.017926], ['design', 0.017236]]
# row   26: sub=1, clust=0, top term=china (wt=0.108903) [['china', 0.108903], ['take next', 0.080186], ['operator take', 0.070821], ['december', 0.018527], ['september', 0.0141]]
# row   27: sub=0, clust=0, top term=train (wt=0.044818) [['train', 0.044818], ['network', 0.03079], ['question line', 0.027813], ['productivity', 0.024773], ['mexico', 0.023463]]
# row   28: sub=0, clust=0, top term=come line (wt=0.086321) [['come line', 0.086321], ['organization', 0.007248], ['feel good', 0.006645], ['back half', 0.005798], ['really good', 0.005376]]
# row   29: sub=0, clust=1, top term=store (wt=0.200999) [['store', 0.200999], ['comp', 0.054356], ['online', 0.019305], ['traffic', 0.018468], ['retail', 0.014849]]
# row   30: sub=0, clust=1, top term=tool (wt=0.16287) [['tool', 0.16287], ['new product', 0.022916], ['currency', 0.020906], ['critical', 0.020377], ['unfavorable', 0.02026]]
# row   31: sub=1, clust=1, top term=senior (wt=0.19277) [['senior', 0.19277], ['senior vice', 0.111769], ['yeah', 0.088625], ['markets', 0.059081], ['capital markets', 0.050387]]
# row   32: sub=0, clust=1, top term=cloud (wt=0.162794) [['cloud', 0.162794], ['enterprise', 0.063774], ['data', 0.026049], ['datum center', 0.023923], ['provider', 0.022085]]
# row   33: sub=0, clust=1, top term=currency (wt=0.191454) [['currency', 0.191454], ['constant', 0.113259], ['constant currency', 0.097106], ['new product', 0.007992], ['americas', 0.007596]]
# row   34: sub=0, clust=1, top term=loan (wt=0.104693) [['loan', 0.104693], ['deposit', 0.0545], ['net interest', 0.018565], ['ratio', 0.018328], ['fee', 0.01766]]
# row   35: sub=0, clust=1, top term=marketing (wt=0.105276) [['marketing', 0.105276], ['user', 0.04894], ['app', 0.032198], ['mobile', 0.028418], ['advertising', 0.020679]]
# row   36: sub=0, clust=1, top term=land (wt=0.098354) [['land', 0.098354], ['community', 0.078315], ['housing', 0.05878], ['california', 0.022716], ['construction', 0.022117]]
# row   37: sub=0, clust=1, top term=test (wt=0.133769) [['test', 0.133769], ['testing', 0.111028], ['recur', 0.059243], ['reference', 0.017539], ['practice', 0.014144]]
# row   38: sub=0, clust=1, top term=us (wt=0.135916) [['us', 0.135916], ['raw', 0.073853], ['raw material', 0.063786], ['inflation', 0.017743], ['price increase', 0.015149]]
# row   39: sub=0, clust=1, top term=air (wt=0.133143) [['air', 0.133143], ['fleet', 0.100572], ['ebitda', 0.024271], ['capex', 0.022963], ['turn slide', 0.016834]]
# row   40: sub=0, clust=1, top term=device (wt=0.173901) [['device', 0.173901], ['currency', 0.048232], ['constant', 0.030772], ['office', 0.028779], ['constant currency', 0.024657]]
# row   41: sub=0, clust=1, top term=digital (wt=0.119614) [['digital', 0.119614], ['innovation', 0.032725], ['connect', 0.017533], ['engagement', 0.01603], ['app', 0.015136]]
# row   42: sub=0, clust=1, top term=agreement (wt=0.038689) [['agreement', 0.038689], ['quarter million', 0.035227], ['diluted', 0.03283], ['compare million', 0.032064], ['net income', 0.031496]]
# row   43: sub=0, clust=1, top term=ai (wt=0.156049) [['ai', 0.156049], ['design', 0.038246], ['software', 0.022898], ['data', 0.014692], ['innovation', 0.011934]]
# row   44: sub=0, clust=1, top term=estate (wt=0.130977) [['estate', 0.130977], ['real estate', 0.125694], ['ratio', 0.011993], ['market share', 0.010191], ['yield', 0.009815]]
# row   45: sub=1, clust=1, top term=chairman (wt=0.218506) [['chairman', 0.218506], ['chairman chief', 0.095731], ['chairman president', 0.080177], ['president chief', 0.072312], ['llc', 0.041546]]
# row   46: sub=0, clust=1, top term=covid (wt=0.335721) [['covid', 0.335721], ['vaccine', 0.057338], ['pandemic', 0.036373], ['recovery', 0.023709], ['test', 0.017707]]
# row   47: sub=0, clust=1, top term=digital (wt=0.10844) [['digital', 0.10844], ['news', 0.081718], ['advertising', 0.051259], ['australia', 0.028066], ['ebitda', 0.026295]]
# row   48: sub=0, clust=1, top term=rating (wt=0.071898) [['rating', 0.071898], ['finance', 0.055664], ['bond', 0.019851], ['percent', 0.019414], ['incentive', 0.017753]]
# row   49: sub=0, clust=1, top term=claim (wt=0.108202) [['claim', 0.108202], ['reserve', 0.094204], ['premium', 0.027328], ['individual', 0.021067], ['care', 0.019693]]
# row   50: sub=0, clust=1, top term=premium (wt=0.058473) [['premium', 0.058473], ['ratio', 0.054433], ['insurance', 0.03418], ['property', 0.030181], ['book', 0.026747]]
# row   51: sub=0, clust=1, top term=equipment (wt=0.197488) [['equipment', 0.197488], ['practice', 0.025497], ['local', 0.02184], ['currency', 0.020553], ['internal', 0.019373]]
# row   52: sub=0, clust=1, top term=pandemic (wt=0.110223) [['pandemic', 0.110223], ['recovery', 0.038179], ['march', 0.029726], ['liquidity', 0.023072], ['safety', 0.018674]]
# row   53: sub=0, clust=1, top term=york (wt=0.104224) [['york', 0.104224], ['new york', 0.100928], ['water', 0.068654], ['city', 0.036251], ['american', 0.028573]]
# row   54: sub=0, clust=1, top term=pro (wt=0.135814) [['pro', 0.135814], ['season', 0.074368], ['net revenue', 0.056667], ['online', 0.013604], ['block', 0.013481]]
# row   55: sub=0, clust=1, top term=payment (wt=0.09721) [['payment', 0.09721], ['card', 0.079597], ['merchant', 0.04644], ['partnership', 0.015374], ['digital', 0.01511]]
# row   56: sub=0, clust=1, top term=guest (wt=0.097155) [['guest', 0.097155], ['member', 0.049039], ['barrel', 0.026178], ['heavy', 0.019059], ['capture', 0.017838]]
# row   57: sub=0, clust=1, top term=rent (wt=0.054919) [['rent', 0.054919], ['lease', 0.050161], ['property', 0.037194], ['occupancy', 0.033694], ['cap', 0.019096]]
# row   58: sub=0, clust=1, top term=japan (wt=0.181892) [['japan', 0.181892], ['hedge', 0.0564], ['sector', 0.039913], ['ratio', 0.022827], ['policy', 0.01504]]
# row   59: sub=0, clust=1, top term=hotel (wt=0.099005) [['hotel', 0.099005], ['room', 0.066611], ['property', 0.047104], ['fee', 0.02582], ['brand', 0.023249]]
# row   60: sub=0, clust=1, top term=tariff (wt=0.122932) [['tariff', 0.122932], ['trade', 0.018103], ['marketplace', 0.011935], ['list', 0.009877], ['price increase', 0.009586]]
# row   61: sub=1, clust=1, top term=president chief (wt=0.179526) [['president chief', 0.179526], ['director', 0.154203], ['executive vice', 0.117947], ['broker', 0.035463], ['llc', 0.034737]]
# row   62: sub=0, clust=1, top term=chain (wt=0.159981) [['chain', 0.159981], ['supply chain', 0.151662], ['constraint', 0.022183], ['transportation', 0.015246], ['automation', 0.013898]]
# row   63: sub=0, clust=1, top term=specialty (wt=0.097241) [['specialty', 0.097241], ['wells', 0.021135], ['volume growth', 0.014889], ['brazil', 0.014887], ['hedge', 0.013167]]
# row   64: sub=0, clust=1, top term=division (wt=0.282208) [['division', 0.282208], ['research division', 0.159895], ['llc', 0.021363], ['capital markets', 0.015033], ['markets', 0.0133]]
# row   65: sub=0, clust=1, top term=insurance (wt=0.063214) [['insurance', 0.063214], ['analytic', 0.061517], ['subscription', 0.056463], ['transition', 0.044537], ['energy', 0.020182]]
# row   66: sub=0, clust=1, top term=storage (wt=0.127467) [['storage', 0.127467], ['internal', 0.050889], ['recall', 0.028134], ['street', 0.020107], ['come line', 0.015218]]
# row   67: sub=0, clust=1, top term=weather (wt=0.131561) [['weather', 0.131561], ['march', 0.021689], ['season', 0.015128], ['february', 0.012866], ['freight', 0.010845]]
# row   68: sub=0, clust=1, top term=buyer (wt=0.182525) [['buyer', 0.182525], ['active', 0.040179], ['option', 0.020991], ['land', 0.018338], ['community', 0.014673]]
# row   69: sub=0, clust=1, top term=foot (wt=0.076824) [['foot', 0.076824], ['square', 0.06964], ['lease', 0.060217], ['square foot', 0.055229], ['building', 0.041103]]
# row   70: sub=2, clust=1, top term=care (wt=0.149136) [['care', 0.149136], ['health', 0.124665], ['patient', 0.04471], ['hospital', 0.031981], ['facility', 0.016834]]
# row   71: sub=0, clust=1, top term=proceed (wt=0.206956) [['proceed', 0.206956], ['proceed question', 0.133582], ['please proceed', 0.128236], ['come line', 0.0498], ['question line', 0.011286]]
# row   72: sub=0, clust=1, top term=yield (wt=0.134874) [['yield', 0.134874], ['ship', 0.072669], ['book', 0.030273], ['brand', 0.027992], ['fuel', 0.017898]]
# row   73: sub=0, clust=1, top term=food (wt=0.092507) [['food', 0.092507], ['restaurant', 0.083753], ['delivery', 0.029316], ['comp', 0.023437], ['labor', 0.023112]]
# row   74: sub=0, clust=1, top term=synergy (wt=0.145365) [['synergy', 0.145365], ['integration', 0.105922], ['legacy', 0.043845], ['integrate', 0.025184], ['saving', 0.022627]]
# row   75: sub=0, clust=1, top term=security (wt=0.12685) [['security', 0.12685], ['software', 0.093184], ['application', 0.045736], ['enterprise', 0.021506], ['infrastructure', 0.013892]]
# row   76: sub=2, clust=1, top term=patient (wt=0.098689) [['patient', 0.098689], ['study', 0.044412], ['phase', 0.032721], ['trial', 0.029143], ['therapy', 0.02367]]
# row   77: sub=0, clust=1, top term=booking (wt=0.216276) [['booking', 0.216276], ['travel', 0.138441], ['book', 0.032573], ['direct', 0.013901], ['room', 0.011733]]
# row   78: sub=2, clust=1, top term=procedure (wt=0.109136) [['procedure', 0.109136], ['hospital', 0.046065], ['patient', 0.029788], ['clinical', 0.021331], ['adoption', 0.017498]]
# row   79: sub=0, clust=1, top term=vehicle (wt=0.117709) [['vehicle', 0.117709], ['truck', 0.052246], ['dealer', 0.040541], ['china', 0.023768], ['production', 0.023098]]
# row   80: sub=0, clust=1, top term=auto (wt=0.135059) [['auto', 0.135059], ['car', 0.074113], ['policy', 0.019981], ['ratio', 0.018235], ['direct', 0.015197]]
# row   81: sub=0, clust=1, top term=home (wt=0.334271) [['home', 0.334271], ['gross margin', 0.01412], ['incentive', 0.014034], ['housing', 0.012834], ['count', 0.008109]]
# row   82: sub=2, clust=1, top term=healthcare (wt=0.058394) [['healthcare', 0.058394], ['medical', 0.053059], ['health', 0.043839], ['member', 0.031333], ['care', 0.030182]]
# row   83: sub=0, clust=1, top term=ebitda (wt=0.172059) [['ebitda', 0.172059], ['adjust ebitda', 0.0621], ['ebitda margin', 0.03712], ['venture', 0.018587], ['joint', 0.015736]]
# row   84: sub=0, clust=1, top term=content (wt=0.104317) [['content', 0.104317], ['game', 0.067188], ['player', 0.031071], ['sport', 0.027423], ['mobile', 0.023174]]
# row   85: sub=0, clust=1, top term=exchange (wt=0.110856) [['exchange', 0.110856], ['foreign', 0.104853], ['foreign exchange', 0.081658], ['sequentially', 0.032994], ['sequential', 0.01806]]
# row   86: sub=0, clust=1, top term=life (wt=0.063304) [['life', 0.063304], ['retirement', 0.034685], ['interest rate', 0.029131], ['ratio', 0.019421], ['variable', 0.018485]]
# row   87: sub=1, clust=1, top term=llc (wt=0.139721) [['llc', 0.139721], ['securities llc', 0.048807], ['markets', 0.040539], ['yeah', 0.036412], ['lynch', 0.032111]]
# row   88: sub=0, clust=1, top term=express (wt=0.147459) [['express', 0.147459], ['ground', 0.098676], ['package', 0.054602], ['option', 0.024066], ['peak', 0.023033]]
# row   89: sub=0, clust=1, top term=solutions (wt=0.142157) [['solutions', 0.142157], ['mortgage', 0.04265], ['transformation', 0.033699], ['new product', 0.022124], ['services', 0.019477]]
# row   90: sub=0, clust=1, top term=construction (wt=0.086032) [['construction', 0.086032], ['texas', 0.050794], ['aggregate', 0.033503], ['infrastructure', 0.021163], ['california', 0.016855]]
# row   91: sub=2, clust=2, top term=fund (wt=0.060067) [['fund', 0.060067], ['fee', 0.051008], ['equity', 0.049558], ['client', 0.034197], ['private', 0.029486]]
# row   92: sub=1, clust=2, top term=trading (wt=0.063168) [['trading', 0.063168], ['trade', 0.059464], ['option', 0.030564], ['index', 0.027405], ['client', 0.021225]]
# row   93: sub=0, clust=2, top term=client (wt=0.081967) [['client', 0.081967], ['fee', 0.038607], ['wealth', 0.027225], ['deposit', 0.026353], ['banking', 0.023318]]
# row   94: sub=0, clust=2, top term=client (wt=0.22997) [['client', 0.22997], ['retention', 0.018155], ['new business', 0.015543], ['agency', 0.01527], ['talent', 0.014466]]
# row   95: sub=1, clust=3, top term=brand (wt=0.088151) [['brand', 0.088151], ['retail', 0.072138], ['channel', 0.047175], ['wholesale', 0.035478], ['store', 0.021523]]
# row   96: sub=1, clust=3, top term=brand (wt=0.216955) [['brand', 0.216955], ['innovation', 0.027693], ['marketing', 0.026428], ['retailer', 0.019891], ['saving', 0.015082]]
# row   97: sub=2, clust=3, top term=net sale (wt=0.100041) [['net sale', 0.100041], ['market share', 0.038637], ['profit', 0.028532], ['retail', 0.025142], ['currency', 0.023519]]
# row   98: sub=0, clust=3, top term=fiscal (wt=0.073283) [['fiscal', 0.073283], ['profit', 0.053042], ['gross profit', 0.036274], ['brand', 0.026018], ['freight', 0.015416]]
# row   99: sub=0, clust=3, top term=fiscal (wt=0.360301) [['fiscal', 0.360301], ['fiscal year', 0.137935], ['quarter fiscal', 0.042187], ['calendar', 0.016231], ['diluted', 0.00651]]
#
# ===================Summary===================
#                                            file_name
# 0  LDA_100_topic_word_norm_with_4_with_subcluster...
# Preview frame results:
#                                            file_name  topic_id  subcluster_id  \
# 0  LDA_100_topic_word_norm_with_4_with_subcluster...         0              2
# 1  LDA_100_topic_word_norm_with_4_with_subcluster...         1              0
# 2  LDA_100_topic_word_norm_with_4_with_subcluster...         2              0
# 3  LDA_100_topic_word_norm_with_4_with_subcluster...         3              1
# 4  LDA_100_topic_word_norm_with_4_with_subcluster...         4              0
#
#   cluster_id                                             topics  absolutely  \
# 0          0  [[organic, 0.230976], [organic growth, 0.09574...    0.001398
# 1          0  [[aircraft, 0.061866], [united, 0.021051], [fl...    0.002064
# 2          0  [[plant, 0.064305], [packaging, 0.036433], [to...    0.000478
# 3          0  [[gross margin, 0.114848], [shipment, 0.040261...    0.000829
# 4          0  [[gas, 0.120051], [energy, 0.070837], [natural...    0.000520
#
#    acceleration  accounting  accretive   acquire  ...  year expect   year go  \
# 0      0.001732    0.001052   0.001950  0.007201  ...     0.000650  0.000600
# 1      0.000154    0.000530   0.000455  0.000113  ...     0.001611  0.001260
# 2      0.000040    0.000118   0.000190  0.000659  ...     0.001234  0.000827
# 3      0.000617    0.000190   0.000135  0.000577  ...     0.001337  0.000435
# 4      0.000024    0.000167   0.000595  0.001406  ...     0.000527  0.000313
#
#    year look  year quarter  year see  year would  year year     yield  \
# 0   0.000764      0.000271  0.001249    0.000830   0.000386  0.000007
# 1   0.000902      0.000038  0.000725    0.000806   0.001476  0.002910
# 2   0.000812      0.000190  0.001275    0.000445   0.000632  0.000452
# 3   0.000246      0.000380  0.000895    0.000483   0.001292  0.000017
# 4   0.000459      0.000327  0.001072    0.000574   0.000510  0.000819
#
#            york              topic_name
# 0  2.185418e-07          Organic Growth
# 1  2.362675e-04         Fleet Expansion
# 2  5.571611e-08       Production Volume
# 3  6.201966e-08            Gross Margin
# 4  3.363482e-05  Natural Gas Operations
#
# [5 rows x 1006 columns]

# %%
"""
    Run subcluster and clusting action through GPT. More precise prompt due to data requirements of maintaining keys
"""

for rec in results_df.itertuples(index=False):
    file_name  = rec.file_name
    inner_df = rec.inner_df.copy()

    # Idea for chatgpt to keep key strings separate from learning strings
    inner_df["key1"] = "$" + inner_df["topic_id"].astype(str) + "$"
    inner_df["key2"] = "$" + inner_df["topic_name"] + "$"

    # Select sending columns
    send_it = inner_df[[
        "file_name","key1", "key2", "topic_id", "subcluster_id","cluster_id", "topic_name"
    ]]

    def dataframe_to_markdown(df: pd.DataFrame, include_index: bool = False) -> str:
        # Convert dataframe to markdown for improving GPT's structure understanding
        if include_index:
            df = df.reset_index()
        columns = df.columns.tolist()
        headings = "| " + " | ".join(columns) + " |"
        deliminator = "| " + " | ".join("---" for _ in columns) + " |"
        body_lines = []
        for row in df.itertuples(index=False, name=None):
            cells = [str(cell) for cell in row]
            body_lines.append("| " + " | ".join(cells) + " |")
        return "\n".join([headings, deliminator] + body_lines)
    
    readable = dataframe_to_markdown(send_it)

    base_prompt = """
        CONTEXT:
        Every quarter, S&P 500 companies hold earnings calls to discuss financial results.
        We’ve extracted topic vectors (5 weighted terms each) clustered into 
        topic_id → subcluster_id → cluster_id.
        topic_name → subcluster_name → cluster_name.

        YOUR TASK:
        1. You will receive a single row as a CSV with these columns:
        • file_name
        • key1
        • key2
        • topic_id
        • topic_name
        • subcluster_id
        • topics (5 term:weight pairs)

        2. ADD TWO NEW COLUMNS:
        • subcluster_name
        • cluster_name

        3. SUBCLUSTER_NAME should be a summary of the topic_name that can be grouped underneath it

        4. CLUSTER_NAME MUST BE CHOSEN FROM:
            Economic & Financial
            Technological & Digital
            Environmental & Resource
            Social & Consumer
            Corporate Strategy & Execution
            – Try to assign at least two different clusters per file.
            – each SUBCLUSTER_NAME must be grouped into one CLUSTER_NAME
            
        TRY TO HAVE NO MORE THAN 15 UNIQUE SUBCLUSTER_NAME in the output

        4. YOU MUST NOT MODIFY:
        file_name, key1, key2, topic_id, topic_name
        – They must exactly match the input row, in the same order.

        5. OUTPUT:
        Return **only** a CSV (no extra text) with **all** 100 rows,
        and these columns in this order:
        file_name, key1, key2, topic_id, topic_name, 
        subcluster_id, subcluster_name, cluster_name, cluster_id

        # !!! BEFORE RETURNING:
        • VERIFY that file_name, key1 and key2 are unchanged for every row.
        • DO NOT include any leading/trailing comments—CSV ONLY.
    """

    prompt = base_prompt + f"\n\nDataframe to analyze:\n{readable}\n"
    print("================PROMPT================")
    display(prompt)
    caller = get_chatgpt_response(prompt, model="gpt-4.1")
    print("================RESPONSE================")
    display(caller)
    csv_text = caller.strip()
    
    # Execute post-processing
    df_response = pd.read_csv(StringIO(csv_text))
    inner_df = df_response
    print(f"Processed {file_name}, got columns: {inner_df.columns.tolist()}")
# Out:
# ================PROMPT================
# '\n        CONTEXT:\n        Every quarter, S&P\xa0500 companies hold earnings calls to discuss financial results.\n        We’ve extracted topic vectors (5 weighted terms each) clustered into \n        topic_id → subcluster_id → cluster_id.\n        topic_name → subcluster_name → cluster_name.\n\n        YOUR TASK:\n        1. You will receive a single row as a CSV with these columns:\n        • file_name\n        • key1\n        • key2\n        • topic_id\n        • topic_name\n        • subcluster_id\n        • topics (5 term:weight pairs)\n\n        2. ADD TWO NEW COLUMNS:\n        • subcluster_name\n        • cluster_name\n\n        3. SUBCLUSTER_NAME should be a summary of the topic_name that can be grouped underneath it\n\n        4. CLUSTER_NAME MUST BE CHOSEN FROM:\n            Economic & Financial\n            Technological & Digital\n            Environmental & Resource\n            Social & Consumer\n            Corporate Strategy & Execution\n            –\xa0Try to assign at least two different clusters per file.\n            –\xa0each SUBCLUSTER_NAME must be grouped into one CLUSTER_NAME\n\n        TRY TO HAVE NO MORE THAN 15 UNIQUE SUBCLUSTER_NAME in the output\n\n        4. YOU MUST NOT MODIFY:\n        file_name, key1, key2, topic_id, topic_name\n        – They must exactly match the input row, in the same order.\n\n        5. OUTPUT:\n        Return **only** a CSV (no extra text) with **all** 100 rows,\n        and these columns in this order:\n        file_name, key1, key2, topic_id, topic_name, \n        subcluster_id, subcluster_name, cluster_name, cluster_id\n\n        !!! BEFORE RETURNING:\n        • VERIFY that file_name, key1 and key2 are unchanged for every row.\n        • DO NOT include any leading/trailing comments—CSV ONLY.\n    \n\nDataframe to analyze:\n| file_name | key1 | key2 | topic_id | subcluster_id | cluster_id | topic_name |\n| --- | --- | --- | --- | --- | --- | --- |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $0$ | $Organic Growth$ | 0 | 2 | 0 | Organic Growth |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $1$ | $Fleet Expansion$ | 1 | 0 | 0 | Fleet Expansion |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $2$ | $Production Volume$ | 2 | 0 | 0 | Production Volume |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $3$ | $Gross Margin$ | 3 | 1 | 0 | Gross Margin |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $4$ | $Natural Gas Operations$ | 4 | 0 | 0 | Natural Gas Operations |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $5$ | $Fuel Costs$ | 5 | 0 | 0 | Fuel Costs |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $6$ | $Oil Production Volume$ | 6 | 0 | 0 | Oil Production Volume |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $7$ | $Profitability Drivers$ | 7 | 0 | 0 | Profitability Drivers |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $8$ | $Revenue Recovery$ | 8 | 0 | 0 | Revenue Recovery |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $9$ | $Energy Utilities$ | 9 | 0 | 0 | Energy Utilities |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $10$ | $Network Deployment$ | 10 | 0 | 0 | Network Deployment |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $11$ | $Automotive Segment$ | 11 | 0 | 0 | Automotive Segment |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $12$ | $Backlog Valuation$ | 12 | 0 | 0 | Backlog Valuation |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $13$ | $Industrial Oil Markets$ | 13 | 0 | 0 | Industrial Oil Markets |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $14$ | $Growth Metrics$ | 14 | 1 | 0 | Growth Metrics |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $15$ | $Production Output$ | 15 | 0 | 0 | Production Output |\n| LDA_100_topic_word_norm_with_4_with_subclusters.csv | $16$ | $Residential Water Inflation$ | 16 | 1 | 0 | Residential Water Inflation |\n| LDA_100_topic_word_norm_with_4_with_ ...
# ================RESPONSE================
# 'file_name,key1,key2,topic_id,topic_name,subcluster_id,subcluster_name,cluster_name,cluster_id\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$0$,$Organic Growth$,0,Organic Growth,2,Growth,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$1$,$Fleet Expansion$,1,Fleet Expansion,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$2$,$Production Volume$,2,Production Volume,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$3$,$Gross Margin$,3,Gross Margin,1,Profitability Metrics,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$4$,$Natural Gas Operations$,4,Natural Gas Operations,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$5$,$Fuel Costs$,5,Fuel Costs,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$6$,$Oil Production Volume$,6,Oil Production Volume,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$7$,$Profitability Drivers$,7,Profitability Drivers,0,Profitability Metrics,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$8$,$Revenue Recovery$,8,Revenue Recovery,0,Revenue Trends,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$9$,$Energy Utilities$,9,Energy Utilities,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$10$,$Network Deployment$,10,Network Deployment,0,Technology Infrastructure,Technological & Digital,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$11$,$Automotive Segment$,11,Automotive Segment,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$12$,$Backlog Valuation$,12,Backlog Valuation,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$13$,$Industrial Oil Markets$,13,Industrial Oil Markets,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$14$,$Growth Metrics$,14,Growth Metrics,1,Growth,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$15$,$Production Output$,15,Production Output,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$16$,$Residential Water Inflation$,16,Residential Water Inflation,1,Regulated Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$17$,$Wireless EBITDA Margin$,17,Wireless EBITDA Margin,0,Profitability Metrics,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$18$,$Organic Growth$,18,Organic Growth,2,Growth,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$19$,$Emerging Markets$,19,Emerging Markets,1,Markets & Regions,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$20$,$Maintenance Expense$,20,Maintenance Expense,0,Asset & Operations,Corporate Strategy & Execution,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$21$,$Network Revenue$,21,Network Revenue,0,Technology Infrastructure,Technological & Digital,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$22$,$International Revenue$,22,International Revenue,0,Markets & Regions,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$23$,$Inflation Impact$,23,Inflation Impact,1,Macro & Inflation,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$24$,$Rig Utilization$,24,Rig Utilization,0,Energy & Utilities,Environmental & Resource,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$25$,$Gross Margin Trends$,25,Gross Margin Trends,1,Profitability Metrics,Economic & Financial,0\nLDA_100_topic_word_norm_with_4_with_subclusters.csv,$26$,$China Exposure$, ...
# Processed LDA_100_topic_word_norm_with_4_with_subclusters.csv, got columns: ['file_name', 'key1', 'key2', 'topic_id', 'topic_name', 'subcluster_id', 'subcluster_name', 'cluster_name', 'cluster_id']

# %%
"""
  Read and clean export data
"""
csv_text = re.sub(r"^```csv\s*", "", caller) # drop the opening fence
csv_text = re.sub(r"\s*```$", "",  csv_text) # drop the closing fence
csv_text = csv_text.strip() # strip any leading/trailing whitespace
df_response = pd.read_csv(StringIO(csv_text)) # convert to a pandas DataFrame

df_response = df_response.drop(columns=["cluster_id", "subcluster_id"]) # Drop old columns

# Redindex cluster_id alphabetically
cluster_names = sorted(df_response["cluster_name"].unique())
cluster_id_map = {name: i for i, name in enumerate(cluster_names)}
df_response["cluster_id"] = df_response["cluster_name"].map(cluster_id_map)

# Reindex subcluster_id within cluster_id alphabetically
df_response["subcluster_id"] = (
    df_response
        .groupby("cluster_name")["subcluster_name"]
        .transform(lambda s: pd.Categorical(s, categories=sorted(s.unique())).codes)
)

# Preview cleaning
print("===========RESPONSE_DF===========")
display(df_response)

print("===========ORIGINAL_DF===========")
df_original = rec.inner_df.copy()
display(df_original)
# Out:
# ===========RESPONSE_DF===========
#                                             file_name  key1  \
# 0   LDA_100_topic_word_norm_with_4_with_subcluster...   $0$
# 1   LDA_100_topic_word_norm_with_4_with_subcluster...   $1$
# 2   LDA_100_topic_word_norm_with_4_with_subcluster...   $2$
# 3   LDA_100_topic_word_norm_with_4_with_subcluster...   $3$
# 4   LDA_100_topic_word_norm_with_4_with_subcluster...   $4$
# ..                                                ...   ...
# 95  LDA_100_topic_word_norm_with_4_with_subcluster...  $95$
# 96  LDA_100_topic_word_norm_with_4_with_subcluster...  $96$
# 97  LDA_100_topic_word_norm_with_4_with_subcluster...  $97$
# 98  LDA_100_topic_word_norm_with_4_with_subcluster...  $98$
# 99  LDA_100_topic_word_norm_with_4_with_subcluster...  $99$
#
#                         key2  topic_id              topic_name  \
# 0           $Organic Growth$         0          Organic Growth
# 1          $Fleet Expansion$         1         Fleet Expansion
# 2        $Production Volume$         2       Production Volume
# 3             $Gross Margin$         3            Gross Margin
# 4   $Natural Gas Operations$         4  Natural Gas Operations
# ..                       ...       ...                     ...
# 95      $Retail Channel Mix$        95      Retail Channel Mix
# 96       $Brand Performance$        96       Brand Performance
# 97     $Revenue Performance$        97     Revenue Performance
# 98          $Fiscal Results$        98          Fiscal Results
# 99      $Fiscal Performance$        99      Fiscal Performance
#
#           subcluster_name                    cluster_name  cluster_id  \
# 0                  Growth  Corporate Strategy & Execution           0
# 1      Asset & Operations  Corporate Strategy & Execution           0
# 2      Asset & Operations  Corporate Strategy & Execution           0
# 3   Profitability Metrics            Economic & Financial           1
# 4      Energy & Utilities        Environmental & Resource           2
# ..                    ...                             ...         ...
# 95        Brand & Channel               Social & Consumer           3
# 96        Brand & Channel               Social & Consumer           3
# 97        Brand & Channel               Social & Consumer           3
# 98      Financial Results            Economic & Financial           1
# 99      Financial Results            Economic & Financial           1
#
#     subcluster_id
# 0               2
# 1               0
# 2               0
# 3               5
# 4               0
# ..            ...
# 95              0
# 96              0
# 97              0
# 98              1
# 99              1
#
# [100 rows x 9 columns]
# ===========ORIGINAL_DF===========
#                                             file_name  topic_id  \
# 0   LDA_100_topic_word_norm_with_4_with_subcluster...         0
# 1   LDA_100_topic_word_norm_with_4_with_subcluster...         1
# 2   LDA_100_topic_word_norm_with_4_with_subcluster...         2
# 3   LDA_100_topic_word_norm_with_4_with_subcluster...         3
# 4   LDA_100_topic_word_norm_with_4_with_subcluster...         4
# ..                                                ...       ...
# 95  LDA_100_topic_word_norm_with_4_with_subcluster...        95
# 96  LDA_100_topic_word_norm_with_4_with_subcluster...        96
# 97  LDA_100_topic_word_norm_with_4_with_subcluster...        97
# 98  LDA_100_topic_word_norm_with_4_with_subcluster...        98
# 99  LDA_100_topic_word_norm_with_4_with_subcluster...        99
#
#     subcluster_id cluster_id  \
# 0               2          0
# 1               0          0
# 2               0          0
# 3               1          0
# 4               0          0
# ..            ...        ...
# 95              1          3
# 96              1          3
# 97              2          3
# 98              0          3
# 99              0          3
#
#                                                topics  absolutely  \
# 0   [[organic, 0.230976], [organic growth, 0.09574...    0.001398
# 1   [[aircraft, 0.061866], [united, 0.021051], [fl...    0.002064
# 2   [[plant, 0.064305], [packaging, 0.036433], [to...    0.000478
# 3   [[gross margin, 0.114848], [shipment, 0.040261...    0.000829
# 4   [[gas, 0.120051], [energy, 0.070837], [natural...    0.000520
# ..                                                ...         ...
# 95  [[brand, 0.088151], [retail, 0.072138], [chann...    0.001050
# 96  [[brand, 0.216955], [innovation, 0.027693], [m...    0.000740
# 97  [[net sale, 0.100041], [market share, 0.038637...    0.000360
# 98  [[fiscal, 0.073283], [profit, 0.053042], [gros...    0.000737
# 99  [[fiscal, 0.360301], [fiscal year, 0.137935], ...    0.000386
#
#     acceleration  accounting  accretive   acquire  ...  year expect   year go  \
# 0       0.001732    0.001052   0.001950  0.007201  ...     0.000650  0.000600
# 1       0.000154    0.000530   0.000455  0.000113  ...     0.001611  0.001260
# 2       0.000040    0.000118   0.000190  0.000659  ...     0.001234  0.000827
# 3       0.000617    0.000190   0.000135  0.000577  ...     0.001337  0.000435
# 4       0.000024    0.000167   0.000595  0.001406  ...     0.000527  0.000313
# ..           ...         ...        ...       ...  ...          ...       ...
# 95      0.001707    0.000155   0.000574  0.000308  ...     0.001324  0.000247
# 96      0.001690    0.001194   0.000557  0.000911  ...     0.000946  0.000244
# 97      0.001930    0.000739   0.000223  0.000803  ...     0.000797  0.000312
# 98      0.001517    0.000027   0.000991  0.000695  ...     0.001601  0.000588
# 99      0.000747    0.001196   0.000955  0.001599  ...     0.001902  0.000557
#
#     year look  year quarter  year see  year would  year year         yield  \
# 0    0.000764      0.000271  0.001249    0.000830   0.000386  6.670445e-06
# 1    0.000902      0.000038  0.000725    0.000806   0.001476  2.910178e-03
# 2    0.000812      0.000190  0.001275    0.000445   0.000632  4.517502e-04
# 3    0.000246      0.000380  0.000895    0.000483   0.001292  1.671633e-05
# 4    0.000459      0.000327  0.001072    0.000574   0.000510  8.193279e-04
# ..        ...           ...       ...         ...        ...           ...
# 95   0.000535      0.000217  0.000774    0.000089   0.000200  5.192086e-08
# 96   0.000605      0.000056  0.000478    0.000598   0.000468  1.127390e-06
# 97   0.000180      0.000273  0.000317    0.000459   0.000121  7.275657e-08
# 98   0.000407      0.001968  0.000400    0.001446   0.000189  4.805660e-05
# 99   0.000645      0.000882  0.001225    0.000811   0.000805  3.703650e-05
#
#             york              topic_name
# 0   2.185418e-07          Organic Growth
# 1   2.362675e-04         Fleet Expansion
# 2   5.571611e-08       Production Volume
# 3   6.201966e-08            Gross Margin
# 4   3.363482e-05  Natural Gas Operations
# ..           ...                     ...
# 95  6.963468e-04      Retail Channel Mix
# 96  1.396094e-06       Brand Performance
# 97  7.504904e-08     Revenue Performance
# 98  8.932758e-08          Fiscal Results
# 99  3.725619e-07      Fiscal Performance
#
# [100 rows x 1006 columns]

# %%
"""
    Reorder and export output
"""

BASE_OUT = Path("output")
ts_folder = BASE_OUT / datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
ts_folder.mkdir(parents=True, exist_ok=True)
print("Saving files to →", ts_folder)

INPUT_DIR = Path("input")
ORDER_DIR = Path("order")

inner_df = rec.inner_df
file_name = rec.file_name

prep = df_original.rename(columns={
        'topic_name': 'topic_name_orig'
        , 'subcluster_id': 'subcluster_id_orig'
        , 'cluster_id': 'cluster_id_orig'}
    ).copy()

keys = ["topic_id"]
vals = [ "topic_name", "subcluster_id", "subcluster_name", "cluster_id", "cluster_name"]
df_merged = prep.merge(
    df_response[keys + vals],
    on=keys,
    how="left",
)

display(df_merged)

# Drop and reorder columns
export = df_merged.drop(columns=["file_name"], errors="ignore")
front_cols = [
    "topic_id",
    "topic_name",
    "topic_name_orig",
    "topics",
    "subcluster_id",
    "subcluster_id_orig",
    "subcluster_name",
    "cluster_id",
    "cluster_id_orig",
    "cluster_name",
]
front_cols = [c for c in front_cols if c in export.columns]
export = export[front_cols + [c for c in export.columns if c not in front_cols]]

display(export)

# Apply ordering from ordering file to regain initial topic importance
stem_prefix = Path(file_name).stem[:7]
order_file = next(f for f in ORDER_DIR.glob("*.csv") if f.stem.startswith(stem_prefix))

# Merge in order from Absolutely column's weights
order_df = pd.read_csv(order_file, usecols=["absolutely"])
order_df["__row_rank"] = range(len(order_df))
export = (
    export
        .merge(order_df, on="absolutely", how="left")
        .sort_values("__row_rank", kind="mergesort")
        .drop(columns="__row_rank")
        .reset_index(drop=True)
)

display(export)

# Reset topic_id to match new order
export["topic_id"] = export.index
columns = ["topic_id"] + [c for c in export.columns if c != "topic_id"]
export = export[columns]

display(export)

# Save to outputs/timestamp
out_path = ts_folder / Path(file_name).name
export.to_csv(out_path, index=False)
print(f"✓ saved {out_path}")
# Out:
# Saving files to → output/2025-04-20_17-51-22
#                                             file_name  topic_id  \
# 0   LDA_100_topic_word_norm_with_4_with_subcluster...         0
# 1   LDA_100_topic_word_norm_with_4_with_subcluster...         1
# 2   LDA_100_topic_word_norm_with_4_with_subcluster...         2
# 3   LDA_100_topic_word_norm_with_4_with_subcluster...         3
# 4   LDA_100_topic_word_norm_with_4_with_subcluster...         4
# ..                                                ...       ...
# 95  LDA_100_topic_word_norm_with_4_with_subcluster...        95
# 96  LDA_100_topic_word_norm_with_4_with_subcluster...        96
# 97  LDA_100_topic_word_norm_with_4_with_subcluster...        97
# 98  LDA_100_topic_word_norm_with_4_with_subcluster...        98
# 99  LDA_100_topic_word_norm_with_4_with_subcluster...        99
#
#     subcluster_id_orig cluster_id_orig  \
# 0                    2               0
# 1                    0               0
# 2                    0               0
# 3                    1               0
# 4                    0               0
# ..                 ...             ...
# 95                   1               3
# 96                   1               3
# 97                   2               3
# 98                   0               3
# 99                   0               3
#
#                                                topics  absolutely  \
# 0   [[organic, 0.230976], [organic growth, 0.09574...    0.001398
# 1   [[aircraft, 0.061866], [united, 0.021051], [fl...    0.002064
# 2   [[plant, 0.064305], [packaging, 0.036433], [to...    0.000478
# 3   [[gross margin, 0.114848], [shipment, 0.040261...    0.000829
# 4   [[gas, 0.120051], [energy, 0.070837], [natural...    0.000520
# ..                                                ...         ...
# 95  [[brand, 0.088151], [retail, 0.072138], [chann...    0.001050
# 96  [[brand, 0.216955], [innovation, 0.027693], [m...    0.000740
# 97  [[net sale, 0.100041], [market share, 0.038637...    0.000360
# 98  [[fiscal, 0.073283], [profit, 0.053042], [gros...    0.000737
# 99  [[fiscal, 0.360301], [fiscal year, 0.137935], ...    0.000386
#
#     acceleration  accounting  accretive   acquire  ...  year would  year year  \
# 0       0.001732    0.001052   0.001950  0.007201  ...    0.000830   0.000386
# 1       0.000154    0.000530   0.000455  0.000113  ...    0.000806   0.001476
# 2       0.000040    0.000118   0.000190  0.000659  ...    0.000445   0.000632
# 3       0.000617    0.000190   0.000135  0.000577  ...    0.000483   0.001292
# 4       0.000024    0.000167   0.000595  0.001406  ...    0.000574   0.000510
# ..           ...         ...        ...       ...  ...         ...        ...
# 95      0.001707    0.000155   0.000574  0.000308  ...    0.000089   0.000200
# 96      0.001690    0.001194   0.000557  0.000911  ...    0.000598   0.000468
# 97      0.001930    0.000739   0.000223  0.000803  ...    0.000459   0.000121
# 98      0.001517    0.000027   0.000991  0.000695  ...    0.001446   0.000189
# 99      0.000747    0.001196   0.000955  0.001599  ...    0.000811   0.000805
#
#            yield          york         topic_name_orig  \
# 0   6.670445e-06  2.185418e-07          Organic Growth
# 1   2.910178e-03  2.362675e-04         Fleet Expansion
# 2   4.517502e-04  5.571611e-08       Production Volume
# 3   1.671633e-05  6.201966e-08            Gross Margin
# 4   8.193279e-04  3.363482e-05  Natural Gas Operations
# ..           ...           ...                     ...
# 95  5.192086e-08  6.963468e-04      Retail Channel Mix
# 96  1.127390e-06  1.396094e-06       Brand Performance
# 97  7.275657e-08  7.504904e-08     Revenue Performance
# 98  4.805660e-05  8.932758e-08          Fiscal Results
# 99  3.703650e-05  3.725619e-07      Fiscal Performance
#
#                 topic_name  subcluster_id        subcluster_name  cluster_id  \
# 0           Organic Growth              2                 Growth           0
# 1          Fleet Expansion              0     Asset & Operations           0
# 2        Production Volume              0     Asset & Operations           0
# 3             Gross Margin              5  Profitability Metrics           1
# 4   Natural Gas Operations              0     Energy & Utilities           2
# ..                     ...            ...                    ...         ...
# 95      Retail Channel Mix              0        Brand & Channel           3
# 96       Brand Performance              0        Brand & Channel           3
# 97     Revenue Performance              0        Brand & Channel           3
# 98          Fiscal Results              1      Financial Results           1
# 99      Fiscal Performance              1      Financial Results           1
#
#                       cluster_name
# 0   Corporate Strategy & Execution
# 1   Corporate Strategy & Execution
# 2   Corporate Strategy & Execution
# 3             Economic & Financial
# 4         Environmental & Resource
# ..                             ...
# 95               Social & Consumer
# 96               Social & Consumer
# 97               Social & Consumer
# 98            Economic & Financial
# 99            Economic & Financial
#
# [100 rows x 1011 columns]
#     topic_id              topic_name         topic_name_orig  \
# 0          0          Organic Growth          Organic Growth
# 1          1         Fleet Expansion         Fleet Expansion
# 2          2       Production Volume       Production Volume
# 3          3            Gross Margin            Gross Margin
# 4          4  Natural Gas Operations  Natural Gas Operations
# ..       ...                     ...                     ...
# 95        95      Retail Channel Mix      Retail Channel Mix
# 96        96       Brand Performance       Brand Performance
# 97        97     Revenue Performance     Revenue Performance
# 98        98          Fiscal Results          Fiscal Results
# 99        99      Fiscal Performance      Fiscal Performance
#
#                                                topics  subcluster_id  \
# 0   [[organic, 0.230976], [organic growth, 0.09574...              2
# 1   [[aircraft, 0.061866], [united, 0.021051], [fl...              0
# 2   [[plant, 0.064305], [packaging, 0.036433], [to...              0
# 3   [[gross margin, 0.114848], [shipment, 0.040261...              5
# 4   [[gas, 0.120051], [energy, 0.070837], [natural...              0
# ..                                                ...            ...
# 95  [[brand, 0.088151], [retail, 0.072138], [chann...              0
# 96  [[brand, 0.216955], [innovation, 0.027693], [m...              0
# 97  [[net sale, 0.100041], [market share, 0.038637...              0
# 98  [[fiscal, 0.073283], [profit, 0.053042], [gros...              1
# 99  [[fiscal, 0.360301], [fiscal year, 0.137935], ...              1
#
#     subcluster_id_orig        subcluster_name  cluster_id cluster_id_orig  \
# 0                    2                 Growth           0               0
# 1                    0     Asset & Operations           0               0
# 2                    0     Asset & Operations           0               0
# 3                    1  Profitability Metrics           1               0
# 4                    0     Energy & Utilities           2               0
# ..                 ...                    ...         ...             ...
# 95                   1        Brand & Channel           3               3
# 96                   1        Brand & Channel           3               3
# 97                   2        Brand & Channel           3               3
# 98                   0      Financial Results           1               3
# 99                   0      Financial Results           1               3
#
#                       cluster_name  ...  year continue  year expect   year go  \
# 0   Corporate Strategy & Execution  ...       0.000886     0.000650  0.000600
# 1   Corporate Strategy & Execution  ...       0.000904     0.001611  0.001260
# 2   Corporate Strategy & Execution  ...       0.000515     0.001234  0.000827
# 3             Economic & Financial  ...       0.000257     0.001337  0.000435
# 4         Environmental & Resource  ...       0.000352     0.000527  0.000313
# ..                             ...  ...            ...          ...       ...
# 95               Social & Consumer  ...       0.001418     0.001324  0.000247
# 96               Social & Consumer  ...       0.000881     0.000946  0.000244
# 97               Social & Consumer  ...       0.000774     0.000797  0.000312
# 98            Economic & Financial  ...       0.001527     0.001601  0.000588
# 99            Economic & Financial  ...       0.001071     0.001902  0.000557
#
#     year look  year quarter  year see  year would  year year         yield  \
# 0    0.000764      0.000271  0.001249    0.000830   0.000386  6.670445e-06
# 1    0.000902      0.000038  0.000725    0.000806   0.001476  2.910178e-03
# 2    0.000812      0.000190  0.001275    0.000445   0.000632  4.517502e-04
# 3    0.000246      0.000380  0.000895    0.000483   0.001292  1.671633e-05
# 4    0.000459      0.000327  0.001072    0.000574   0.000510  8.193279e-04
# ..        ...           ...       ...         ...        ...           ...
# 95   0.000535      0.000217  0.000774    0.000089   0.000200  5.192086e-08
# 96   0.000605      0.000056  0.000478    0.000598   0.000468  1.127390e-06
# 97   0.000180      0.000273  0.000317    0.000459   0.000121  7.275657e-08
# 98   0.000407      0.001968  0.000400    0.001446   0.000189  4.805660e-05
# 99   0.000645      0.000882  0.001225    0.000811   0.000805  3.703650e-05
#
#             york
# 0   2.185418e-07
# 1   2.362675e-04
# 2   5.571611e-08
# 3   6.201966e-08
# 4   3.363482e-05
# ..           ...
# 95  6.963468e-04
# 96  1.396094e-06
# 97  7.504904e-08
# 98  8.932758e-08
# 99  3.725619e-07
#
# [100 rows x 1010 columns]
#     topic_id             topic_name        topic_name_orig  \
# 0         29      Store Performance      Store Performance
# 1         30  Financial Instruments  Financial Instruments
# 2          0         Organic Growth         Organic Growth
# 3         31        Capital Markets        Capital Markets
# 4         95     Retail Channel Mix     Retail Channel Mix
# ..       ...                    ...                    ...
# 95        88       Express Shipping       Express Shipping
# 96        89      Product Offerings      Product Offerings
# 97        28        Revenue Outlook        Revenue Outlook
# 98        94       Client Retention       Client Retention
# 99        90   Construction Revenue   Construction Revenue
#
#                                                topics  subcluster_id  \
# 0   [[store, 0.200999], [comp, 0.054356], [online,...              3
# 1   [[tool, 0.16287], [new product, 0.022916], [cu...              2
# 2   [[organic, 0.230976], [organic growth, 0.09574...              2
# 3   [[senior, 0.19277], [senior vice, 0.111769], [...              2
# 4   [[brand, 0.088151], [retail, 0.072138], [chann...              0
# ..                                                ...            ...
# 95  [[express, 0.147459], [ground, 0.098676], [pac...              0
# 96  [[solutions, 0.142157], [mortgage, 0.04265], [...              3
# 97  [[come line, 0.086321], [organization, 0.00724...              6
# 98  [[client, 0.22997], [retention, 0.018155], [ne...              0
# 99  [[construction, 0.086032], [texas, 0.050794], ...              5
#
#     subcluster_id_orig         subcluster_name  cluster_id cluster_id_orig  \
# 0                    0       Retail & Consumer           3               1
# 1                    0        Financing & Risk           1               1
# 2                    2                  Growth           0               0
# 3                    1        Financing & Risk           1               1
# 4                    1         Brand & Channel           3               3
# ..                 ...                     ...         ...             ...
# 95                   0      Asset & Operations           0               1
# 96                   0       Retail & Consumer           3               1
# 97                   0          Revenue Trends           1               0
# 98                   0  Client & Fund Services           1               2
# 99                   0   Real Estate & Leasing           0               1
#
#                       cluster_name  ...  year continue  year expect   year go  \
# 0                Social & Consumer  ...       0.001149     0.001418  0.000550
# 1             Economic & Financial  ...       0.000066     0.000079  0.000070
# 2   Corporate Strategy & Execution  ...       0.000886     0.000650  0.000600
# 3             Economic & Financial  ...       0.000211     0.000588  0.000418
# 4                Social & Consumer  ...       0.001418     0.001324  0.000247
# ..                             ...  ...            ...          ...       ...
# 95  Corporate Strategy & Execution  ...       0.000189     0.000194  0.000310
# 96               Social & Consumer  ...       0.000951     0.002408  0.000458
# 97            Economic & Financial  ...       0.001809     0.002114  0.001152
# 98            Economic & Financial  ...       0.001031     0.001141  0.000474
# 99  Corporate Strategy & Execution  ...       0.000392     0.000438  0.001364
#
#     year look  year quarter  year see  year would  year year         yield  \
# 0    0.000567      0.001182  0.000764    0.000660   0.001109  2.840055e-08
# 1    0.000290      0.001018  0.000137    0.000156   0.000209  2.292114e-03
# 2    0.000764      0.000271  0.001249    0.000830   0.000386  6.670445e-06
# 3    0.000412      0.000011  0.000838    0.000556   0.002503  6.918441e-05
# 4    0.000535      0.000217  0.000774    0.000089   0.000200  5.192086e-08
# ..        ...           ...       ...         ...        ...           ...
# 95   0.000414      0.000049  0.000533    0.000346   0.001974  1.221889e-02
# 96   0.000078      0.000287  0.000665    0.000289   0.000203  2.238873e-05
# 97   0.001478      0.000161  0.002602    0.002121   0.001228  1.060189e-04
# 98   0.000618      0.000462  0.000903    0.000779   0.000701  7.484136e-05
# 99   0.001625      0.001787  0.002137    0.001566   0.000882  1.582678e-05
#
#             york
# 0   3.382235e-05
# 1   1.288875e-07
# 2   2.185418e-07
# 3   1.129268e-07
# 4   6.963468e-04
# ..           ...
# 95  3.591596e-06
# 96  1.070367e-07
# 97  2.889729e-08
# 98  9.500245e-06
# 99  1.044055e-07
#
# [100 rows x 1010 columns]
#     topic_id             topic_name        topic_name_orig  \
# 0          0      Store Performance      Store Performance
# 1          1  Financial Instruments  Financial Instruments
# 2          2         Organic Growth         Organic Growth
# 3          3        Capital Markets        Capital Markets
# 4          4     Retail Channel Mix     Retail Channel Mix
# ..       ...                    ...                    ...
# 95        95       Express Shipping       Express Shipping
# 96        96      Product Offerings      Product Offerings
# 97        97        Revenue Outlook        Revenue Outlook
# 98        98       Client Retention       Client Retention
# 99        99   Construction Revenue   Construction Revenue
#
#                                                topics  subcluster_id  \
# 0   [[store, 0.200999], [comp, 0.054356], [online,...              3
# 1   [[tool, 0.16287], [new product, 0.022916], [cu...              2
# 2   [[organic, 0.230976], [organic growth, 0.09574...              2
# 3   [[senior, 0.19277], [senior vice, 0.111769], [...              2
# 4   [[brand, 0.088151], [retail, 0.072138], [chann...              0
# ..                                                ...            ...
# 95  [[express, 0.147459], [ground, 0.098676], [pac...              0
# 96  [[solutions, 0.142157], [mortgage, 0.04265], [...              3
# 97  [[come line, 0.086321], [organization, 0.00724...              6
# 98  [[client, 0.22997], [retention, 0.018155], [ne...              0
# 99  [[construction, 0.086032], [texas, 0.050794], ...              5
#
#     subcluster_id_orig         subcluster_name  cluster_id cluster_id_orig  \
# 0                    0       Retail & Consumer           3               1
# 1                    0        Financing & Risk           1               1
# 2                    2                  Growth           0               0
# 3                    1        Financing & Risk           1               1
# 4                    1         Brand & Channel           3               3
# ..                 ...                     ...         ...             ...
# 95                   0      Asset & Operations           0               1
# 96                   0       Retail & Consumer           3               1
# 97                   0          Revenue Trends           1               0
# 98                   0  Client & Fund Services           1               2
# 99                   0   Real Estate & Leasing           0               1
#
#                       cluster_name  ...  year continue  year expect   year go  \
# 0                Social & Consumer  ...       0.001149     0.001418  0.000550
# 1             Economic & Financial  ...       0.000066     0.000079  0.000070
# 2   Corporate Strategy & Execution  ...       0.000886     0.000650  0.000600
# 3             Economic & Financial  ...       0.000211     0.000588  0.000418
# 4                Social & Consumer  ...       0.001418     0.001324  0.000247
# ..                             ...  ...            ...          ...       ...
# 95  Corporate Strategy & Execution  ...       0.000189     0.000194  0.000310
# 96               Social & Consumer  ...       0.000951     0.002408  0.000458
# 97            Economic & Financial  ...       0.001809     0.002114  0.001152
# 98            Economic & Financial  ...       0.001031     0.001141  0.000474
# 99  Corporate Strategy & Execution  ...       0.000392     0.000438  0.001364
#
#     year look  year quarter  year see  year would  year year         yield  \
# 0    0.000567      0.001182  0.000764    0.000660   0.001109  2.840055e-08
# 1    0.000290      0.001018  0.000137    0.000156   0.000209  2.292114e-03
# 2    0.000764      0.000271  0.001249    0.000830   0.000386  6.670445e-06
# 3    0.000412      0.000011  0.000838    0.000556   0.002503  6.918441e-05
# 4    0.000535      0.000217  0.000774    0.000089   0.000200  5.192086e-08
# ..        ...           ...       ...         ...        ...           ...
# 95   0.000414      0.000049  0.000533    0.000346   0.001974  1.221889e-02
# 96   0.000078      0.000287  0.000665    0.000289   0.000203  2.238873e-05
# 97   0.001478      0.000161  0.002602    0.002121   0.001228  1.060189e-04
# 98   0.000618      0.000462  0.000903    0.000779   0.000701  7.484136e-05
# 99   0.001625      0.001787  0.002137    0.001566   0.000882  1.582678e-05
#
#             york
# 0   3.382235e-05
# 1   1.288875e-07
# 2   2.185418e-07
# 3   1.129268e-07
# 4   6.963468e-04
# ..           ...
# 95  3.591596e-06
# 96  1.070367e-07
# 97  2.889729e-08
# 98  9.500245e-06
# 99  1.044055e-07
#
# [100 rows x 1010 columns]
# ✓ saved output/2025-04-20_17-51-22/LDA_100_topic_word_norm_with_4_with_subclusters.csv
